# %% [markdown]
# # Harvest

# %% [markdown]
# How to cache study carrels from the public library

# %%
# pre-configure
from pathlib import Path
LIBRARY = str( Path.home()/'reader-library' )
CARREL = 'homer'

# %%
# require
import rdr

# %%
# download and extract the remote carrel (rdr.download() does this correctly;
# the hand-rolled version here previously referenced undefined TEMPLATE/ZIP/
# CARRELS constants -- see analysis.md A4.12)
rdr.download( CARREL )
