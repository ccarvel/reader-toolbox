# %% [markdown]
# # Build

# %% [markdown]
# This notebook is my sandbox

# %%
DIRECTORY = '../tests/fixtures/mini'
CARREL = 'mini-build-demo'
ERASE     = True

# %%
import rdr

# %%
if __name__ == '__main__' :
    rdr.build( CARREL, DIRECTORY, erase=ERASE )
    rdr.cluster( CARREL, save=True )
    rdr.summarize( CARREL )
    # rdr.read( CARREL )  # opens a real browser window; not safe for headless/CI runs
